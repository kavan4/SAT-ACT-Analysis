# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# _Due to several changes across different states, there has been significant fluctuations to the participation rates and mean scores for the SAT exam.
# <br>
# This report is a summary of the observations from data collected over the 2017-2018 period. The report aims to make recommendations to the College Board for strategies that can help improve participation rates._

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import scipy

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
act_2017 = pd.read_csv("../data/act_2017.csv")
act_2018 = pd.read_csv("../data/act_2018.csv")

sat_2017 = pd.read_csv("../data/sat_2017.csv")
sat_2018 = pd.read_csv("../data/sat_2018.csv")

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
# <br>
# <br>
# _The SAT and ACT are standardized tests for entry in to college/university in the USA. The SAT and ACT generally cover the same topics. Both ACT and SAT scores are used for college admissions decisions and awarding merit-based scholarships. Most colleges do not prefer one test over the other._
#
# - _The ACT includes a test for Science which the SAT does not_
# - _Both of them have optional essay sections_
# - _SAT is scored on a scale of 400-1600_
# - _ACT is scored on a scale of 1-36_

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_2018.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat_2018.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
# <br>
# <br>
# _The data seems to be complete, as in - there are no null values._

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# _Although there are no NaN values, the act_2017 data has the breakdowns by subjects while the act_2018 does not._ <br>

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:

# %% [markdown]
# _The are some issues with the data._
# - _ACT-2017: Composite score for Wyoming has an 'x' with the score._
# - _ACT 2017: Calculating the composite manually by taking the average, the composite column for act_2017 seems to be a little off for most. But the variance is tiny. 0<x<1._
# - _ACT 2017: Calculating manually, the composite score for Maryland seems to be off by ~5points. For the composite score to be 23.6, the Science score should be 23.8._
# - _SAT 2017: Calcualting the totals manualy, most of the totals for sat_2017 are off by 1 point. For Maryland the score seems to be off by 472 points. The score for Math is only 52 which seems to be an error. For Maryland's total to be 1060, the Math score should be 524._
# - _Calculating the totals manually, some of the totals for sat_2018 are a little off. But the variance is tiny. 0<x<1._

# %%
act_2017.iloc[51]
# Out:
# State            Wyoming
# Participation       100%
# English             19.4
# Math                19.8
# Reading             20.8
# Science             20.6
# Composite          20.2x
# Name: 51, dtype: object

# %%
act_2017.iloc[21]
# Out:
# State            Maryland
# Participation         28%
# English              23.3
# Math                 23.1
# Reading              24.2
# Science               2.3
# Composite            23.6
# Name: 21, dtype: object

# %%
sat_2017.iloc[20]
# Out:
# State                                 Maryland
# Participation                              69%
# Evidence-Based Reading and Writing         536
# Math                                        52
# Total                                     1060
# Name: 20, dtype: object

# %%
#manually calculating composite score for act 2017
act_2017_comp = []
act_2017_comp = [(act_2017['English'] + act_2017['Math'] + act_2017['Reading'] + act_2017['Science'])/4]

# %%
act_2017_comp_df = pd.DataFrame(act_2017_comp).T

# %%
#concatenating side by side for easier comparision.
#Not displayed here for ease of reading. 
act_2017_comp_compare = pd.concat([act_2017['Composite'],act_2017_comp_df], axis=1)

# %% [markdown]
# _ACT 2017: Maryland scores off by ~5 points_

# %%
act_2017_comp_compare.iloc[21]
# Out:
# Composite      23.6
# 0            18.225
# Name: 21, dtype: object

# %% [markdown]
# _ACT 2017 Wyoming has 'x'_

# %%
act_2017_comp_compare.iloc[51]
# Out:
# Composite    20.2x
# 0            20.15
# Name: 51, dtype: object

# %%
#manually calculating total score for sat 2017
sat_2017_total = []
sat_2017_total = [sat_2017['Evidence-Based Reading and Writing'] + sat_2017['Math']]

# %%
sat_2017_total_df = pd.DataFrame(sat_2017_total).T

# %%
#concatenating side by side for easier comparision
#not displaying here for ease of reading
sat_2017_total_compare = pd.concat([sat_2017['Total'],sat_2017_total_df], axis=1)

# %% [markdown]
# _SAT 2017 - Maryland's total is off by ~ 500 points_

# %%
sat_2017_total_compare.iloc[20]
# Out:
# Total    1060
# 0         588
# Name: 20, dtype: int64

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %% [markdown]
# _Removing the x from composite column for Wyoming._

# %%
act_2017['Composite'][51] = 20.2
# Out:
# /home/kavan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# _Updating Science score for Maryland to 23.8._

# %%
act_2017['Science'][21] = 23.8
# Out:
# /home/kavan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# _converting values of the composite column to float_

# %%
act_2017['Composite'] = [float(i) for i in act_2017['Composite']]

# %% [markdown]
# _Not really an error - but removing the '%' sign and converting values in the percent column to float in case they need to be used numerically in the future for act_2017_

# %%
act_2017['Participation'] = [i.replace('%','') for i in act_2017['Participation']]

# %%
act_2017['Participation'] = [float(i) for i in act_2017['Participation']]

# %%
act_2017.rename(columns={'Participation':'Participation%'}, inplace=True)

# %% [markdown]
# _Not really an error - but removing the '%' sign and converting values in the percent column to float in case they need to be used numerically in the future for act_2018_

# %%
act_2018['Participation'] = [i.replace('%','') for i in act_2018['Participation']]

# %%
act_2018['Participation'] = [float(i) for i in act_2018['Participation']]

# %%
act_2018.rename(columns={'Participation':'Participation%'}, inplace=True)

# %% [markdown]
# _Updating Maryland's math score to be 524._

# %%
sat_2017.iloc[20]
# Out:
# State                                 Maryland
# Participation                              69%
# Evidence-Based Reading and Writing         536
# Math                                        52
# Total                                     1060
# Name: 20, dtype: object

# %%
sat_2017['Math'][20] = 524
# Out:
# /home/kavan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sat_2017.iloc[20]
# Out:
# State                                 Maryland
# Participation                              69%
# Evidence-Based Reading and Writing         536
# Math                                       524
# Total                                     1060
# Name: 20, dtype: object

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           52 non-null     object
#  1   Participation%  52 non-null     float64
#  2   English         52 non-null     float64
#  3   Math            52 non-null     float64
#  4   Reading         52 non-null     float64
#  5   Science         52 non-null     float64
#  6   Composite       52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           52 non-null     object
#  1   Participation%  52 non-null     float64
#  2   Composite       52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
act_2017.dtypes
# Out:
# State              object
# Participation%    float64
# English           float64
# Math              float64
# Reading           float64
# Science           float64
# Composite         float64
# dtype: object

# %%
act_2018.dtypes
# Out:
# State              object
# Participation%    float64
# Composite         float64
# dtype: object

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# <br>
# _There were some data types which seemed odd. e.g._
# - _Composite for Maryland was object(string)._
# - _Percentages were strings._
# <br>
# <br>
#
# _These have been converted to float in case they are required for future calculations_

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %% [markdown]
# Answer - _Datatypes for ACT have been updated to what they should be in the previous steps._
# <br>
# _Updating the datatypes for SAT 2017._

# %%
sat_2017['Participation'] = [i.replace('%','') for i in sat_2017['Participation']]

# %%
sat_2017['Participation'] = [float(i) for i in sat_2017['Participation']]

# %%
sat_2017.rename(columns={'Participation':'Participation%'}, inplace=True)

# %% [markdown]
# _Updating the datatypes for SAT 2017._

# %%
sat_2018['Participation'] = [i.replace('%','') for i in sat_2018['Participation']]

# %%
sat_2018['Participation'] = [float(i) for i in sat_2018['Participation']]

# %%
sat_2018.rename(columns={'Participation':'Participation%'}, inplace=True)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code already done

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
sat_2017.columns
# Out:
# Index(['State', 'Participation%', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
sat_2018.columns
# Out:
# Index(['State', 'Participation%', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat_2017.dtypes
# Out:
# State                                  object
# Participation%                        float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
sat_2018.dtypes
# Out:
# State                                  object
# Participation%                        float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State              object
# Participation%    float64
# English           float64
# Math              float64
# Reading           float64
# Science           float64
# Composite         float64
# dtype: object

# %%
act_2018.dtypes
# Out:
# State              object
# Participation%    float64
# Composite         float64
# dtype: object

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
act_2017.columns
# Out:
# Index(['State', 'Participation%', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
act_2017.rename(columns={'State':'state', 'Participation%':'act_participation_rate_2017', 'English':'act_english_2017', 'Math':'act_math_2017', 'Reading':'act_reading_2017', 'Science':'act_science_2017','Composite':'act_composite_2017'}, inplace=True)

# %%
act_2017.columns
# Out:
# Index(['state', 'act_participation_rate_2017', 'act_english_2017',
#        'act_math_2017', 'act_reading_2017', 'act_science_2017',
#        'act_composite_2017'],
#       dtype='object')

# %%
act_2018.columns
# Out:
# Index(['State', 'Participation%', 'Composite'], dtype='object')

# %%
act_2018.rename(columns={'State':'state', 'Participation%':'act_participation_rate_2018', 'Composite':'act_composite_2018'}, inplace=True)

# %%
act_2018.columns
# Out:
# Index(['state', 'act_participation_rate_2018', 'act_composite_2018'], dtype='object')

# %%
sat_2017.columns
# Out:
# Index(['State', 'Participation%', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
sat_2017.rename(columns={'State':'state', 'Participation%':'sat_participation_rate_2017',
                         'Evidence-Based Reading and Writing':'sat_reading_writing_2017', 
                         'Math':'sat_math_2017', 'Total':'sat_total_2017'}, inplace=True)

# %%
sat_2017.columns
# Out:
# Index(['state', 'sat_participation_rate_2017', 'sat_reading_writing_2017',
#        'sat_math_2017', 'sat_total_2017'],
#       dtype='object')

# %%
sat_2018.columns
# Out:
# Index(['State', 'Participation%', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
sat_2018.rename(columns={'State':'state', 'Participation%':'sat_participation_rate_2018',
                         'Evidence-Based Reading and Writing':'sat_reading_writing_2018', 
                         'Math':'sat_math_2018', 'Total':'sat_total_2018'}, inplace=True)

# %%
sat_2018.columns
# Out:
# Index(['state', 'sat_participation_rate_2018', 'sat_reading_writing_2018',
#        'sat_math_2018', 'sat_total_2018'],
#       dtype='object')

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT|State Name|
# |sat_participation_rate_2017|float|SAT-2017|The percent of high school students in the state that took the SAT in 2017|
# |sat_reading_writing_2017|int|SAT-2017|The average score on the Evidence-Based Reading and Writing section on the SAT in 2017|
# |sat_math_2017|int|SAT-2017|The average score on the Math section on the SAT in 2017|
# |sat_total_2017|int|SAT-2017|The average total score on the SAT by State in 2017|
# |sat_participation_rate_2018|float|SAT-2018|The percent of high school students in the state that took the SAT in 2018|
# |sat_reading_writing_2018|int|SAT-2018|The average score on the Evidence-Based Reading and Writing section on the SAT in 2018|
# |sat_math_2018|int|SAT-2018|The average score on the Math section on the SAT in 2018|
# |sat_total_2018|int|SAT-2018|The average total score on the SAT by State in 2018|
# |act_participation_rate_2017|float|ACT-2017|The percent of high school students in the state that took the ACT in 2017|
# |act_english_2017|float|ACT-2017|The average score on the English section on the ACT in 2017|
# |act_math_2017|float|ACT-2017|The average score on the Math section on the ACT in 2017|
# |act_reading_2017|float|ACT-2017|The average score on the Reading section on the ACT in 2017|
# |act_science_2017|float|ACT-2017|The average score on the Science section on the ACT in 2017|
# |act_composite_2017|float|ACT-2017|The total score on the ACT for the state in 2017|
# |act_participation_rate_2018|float|ACT-2018|The percent of high school students in the state that took the ACT in 2018|
# |act_composite_2018|float|ACT-2018|The total score on the ACT for the state in 2018|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %% [markdown]
# _The Act2017 dataset contains the national average. While this row might be important, since none of the other datasets have it, it is extra information at this stage. Dropping and resetting index._
# <br>
# <br>
# _The Act2018 dataset contains state of Maine twice for rows 19 and 21. Dropping row 19 and resetting index._

# %%
#code
act_2017.head(1)
# Out:
#       state  act_participation_rate_2017  act_english_2017  act_math_2017  \
# 0  National                         60.0              20.3           20.7
#
#    act_reading_2017  act_science_2017  act_composite_2017
# 0              21.4              21.0                21.0

# %%
#Drop
act_2017.drop([0], inplace=True)

# %%
#Reset Index
act_2017.reset_index(drop=True, inplace=True)

# %%
act_2017.head()
# Out:
#         state  act_participation_rate_2017  act_english_2017  act_math_2017  \
# 0     Alabama                        100.0              18.9           18.4
# 1      Alaska                         65.0              18.7           19.8
# 2     Arizona                         62.0              18.6           19.8
# 3    Arkansas                        100.0              18.9           19.0
# 4  California                         31.0              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8

# %%
#confirm # of cols and rows
act_2017.shape
# Out:
# (51, 7)

# %%
#Maine is displayed twice
act_2018.iloc[19:25]
# Out:
#             state  act_participation_rate_2018  act_composite_2018
# 19          Maine                          7.0                24.0
# 20          Maine                          7.0                24.0
# 21       Maryland                         31.0                22.5
# 22  Massachusetts                         25.0                25.5
# 23       Michigan                         22.0                24.2
# 24      Minnesota                         99.0                21.3

# %%
act_2018.iloc[19]
# Out:
# state                          Maine
# act_participation_rate_2018        7
# act_composite_2018                24
# Name: 19, dtype: object

# %%
#Drop row#19
act_2018.drop([19], inplace=True)

# %%
#reset index
act_2018.reset_index(drop=True, inplace=True)

# %%
#confirm # of rows and cols
act_2018.shape
# Out:
# (51, 3)

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Merging 2017 together:
combined_2017 = pd.merge(act_2017, sat_2017, on='state')

# %%
combined_2017.head()
# Out:
#         state  act_participation_rate_2017  act_english_2017  act_math_2017  \
# 0     Alabama                        100.0              18.9           18.4
# 1      Alaska                         65.0              18.7           19.8
# 2     Arizona                         62.0              18.6           19.8
# 3    Arkansas                        100.0              18.9           19.0
# 4  California                         31.0              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8
#
#    sat_participation_rate_2017  sat_reading_writing_2017  sat_math_2017  \
# 0                          5.0                       593            572
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
combined_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#this step does not seem relevant as the 2018 data is already provided

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %% [markdown]
# _Participation rates are already floats_
# <br>
# <br>
# _Checking and updating State Names where required before merging:_
# - _The states Ohio and Oklahoma have been interchanged for SAT 2018_
# - _C in DC is not capitalized for ACT 2018_

# %%
sat_2018.iloc[35:37]
# Out:
#        state  sat_participation_rate_2018  sat_reading_writing_2018  \
# 35  Oklahoma                          8.0                       541
# 36      Ohio                         18.0                       552
#
#     sat_math_2018  sat_total_2018
# 35            521            1062
# 36            547            1099

# %%
act_2018['state'][8]
# Out:
# 'District of columbia'

# %%
#Fixing Columbia
act_2018['state'][8] = 'District of Columbia'
# Out:
# /home/kavan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
act_2018['state'][8]
# Out:
# 'District of Columbia'

# %%
#Swapping Ohio and Oklahoma for SAT 2018
b, c = sat_2018.iloc[35], sat_2018.iloc[36]

temp = sat_2018.iloc[35].copy()
sat_2018.iloc[35] = c
sat_2018.iloc[36] = temp

# %%
sat_2018.iloc[35:37]
# Out:
#        state  sat_participation_rate_2018  sat_reading_writing_2018  \
# 35      Ohio                         18.0                       552
# 36  Oklahoma                          8.0                       541
#
#     sat_math_2018  sat_total_2018
# 35            547            1099
# 36            521            1062

# %% [markdown]
# _Comparing the state names to make sure there are no issues_
# <br>
# _Code commented out_

# %%
#save original datasets to temp ones
# act_2017_1 = act_2017
# act_2018_1 = act_2018

# sat_2017_1 = sat_2017
# sat_2018_1 = sat_2018

# %%
#rename state columns to different things so they can be compared
# sat_2017_1.rename(columns={'state':'s_17_state'}, inplace=True)
# sat_2018_1.rename(columns={'state':'s_18_state'}, inplace=True)
# act_2017_1.rename(columns={'state':'a_17_state'}, inplace=True)
# act_2018_1.rename(columns={'state':'a_18_state'}, inplace=True)

# %%
#merge the temp dfs to a single one to compare side by side
# states_compare = pd.concat([act_2017_1['a_17_state'], act_2018_1['a_18_state'],sat_2017_1['s_17_state'],sat_2018_1['s_18_state']], axis=1)

# %%
#check if state1 = state2 and state3 and state4 and save to col 1
# states_compare['1'] = states_compare.apply(lambda x: (x.a_17_state==x.a_18_state)and(x.a_17_state==x.s_17_state)and(x.a_17_state==x.s_18_state), axis=1)

# %%
#check if state2 = state3 and state4 and save to col 2
# states_compare['2'] = states_compare.apply(lambda x: (x.a_18_state==x.s_17_state)and(x.a_18_state==x.s_18_state), axis=1)

# %%
#check if state3=state4 and save to col 3
# states_compare['3'] = states_compare.apply(lambda x: (x.s_17_state==x.s_18_state), axis=1)

# %%
#Compare and look for any False values
# states_compare

# %% [markdown]
# _No False values found after all updates. All the state names look good now._
# <br>
# _Merging all data into a single dataset_

# %%
act_2018.head()
# Out:
#         state  act_participation_rate_2018  act_composite_2018
# 0     Alabama                        100.0                19.1
# 1      Alaska                         33.0                20.8
# 2     Arizona                         66.0                19.2
# 3    Arkansas                        100.0                19.4
# 4  California                         27.0                22.7

# %%
#Merging 2018 together
combined_2018 = pd.merge(act_2018, sat_2018, on='state')

# %%
combined_2018.head()
# Out:
#         state  act_participation_rate_2018  act_composite_2018  \
# 0     Alabama                        100.0                19.1
# 1      Alaska                         33.0                20.8
# 2     Arizona                         66.0                19.2
# 3    Arkansas                        100.0                19.4
# 4  California                         27.0                22.7
#
#    sat_participation_rate_2018  sat_reading_writing_2018  sat_math_2018  \
# 0                          6.0                       595            571
# 1                         43.0                       562            544
# 2                         29.0                       577            572
# 3                          5.0                       592            576
# 4                         60.0                       540            536
#
#    sat_total_2018
# 0            1166
# 1            1106
# 2            1149
# 3            1169
# 4            1076

# %%
#Merge 2017 with 2018
final = pd.merge(combined_2017, combined_2018, on='state')

# %%
final.head()
# Out:
#         state  act_participation_rate_2017  act_english_2017  act_math_2017  \
# 0     Alabama                        100.0              18.9           18.4
# 1      Alaska                         65.0              18.7           19.8
# 2     Arizona                         62.0              18.6           19.8
# 3    Arkansas                        100.0              18.9           19.0
# 4  California                         31.0              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8
#
#    sat_participation_rate_2017  sat_reading_writing_2017  sat_math_2017  \
# 0                          5.0                       593            572
# ...

# %%
#Save the contents of this merged dataframe as final.csv
final.to_csv('../data/final.csv')

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe().T
# Out:
#                              count         mean        std    min      25%  \
# act_participation_rate_2017   51.0    65.254902  32.140842    8.0    31.00
# act_english_2017              51.0    20.931373   2.353677   16.3    19.00
# act_math_2017                 51.0    21.182353   1.981989   18.0    19.40
# act_reading_2017              51.0    22.013725   2.067271   18.1    20.45
# act_science_2017              51.0    21.462745   1.753392   18.2    19.95
# act_composite_2017            51.0    21.519608   2.020695   17.8    19.80
# sat_participation_rate_2017   51.0    39.803922  35.276632    2.0     4.00
# sat_reading_writing_2017      51.0   569.117647  45.666901  482.0   533.50
# sat_math_2017                 51.0   556.882353  47.121395  468.0   523.50
# sat_total_2017                51.0  1126.098039  92.494812  950.0  1055.50
# act_participation_rate_2018   51.0    61.725490  34.037085    7.0    28.50
# ...

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#Creating a function so that you can pass just the column name of the required column from the 'Final' dataset
#to get that column's std dev

def man_std(column):
    std_dev = np.sqrt((np.sum((final[column]-np.mean(final[column]))**2)/len(final)))
    return std_dev

# %%
#E.g. - Std Dev of ACT English 2017
man_std('act_english_2017')
# Out:
# 2.3304876369363368

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
final.dtypes
# Out:
# state                           object
# act_participation_rate_2017    float64
# act_english_2017               float64
# act_math_2017                  float64
# act_reading_2017               float64
# act_science_2017               float64
# act_composite_2017             float64
# sat_participation_rate_2017    float64
# sat_reading_writing_2017         int64
# sat_math_2017                    int64
# sat_total_2017                   int64
# act_participation_rate_2018    float64
# act_composite_2018             float64
# sat_participation_rate_2018    float64
# sat_reading_writing_2018         int64
# sat_math_2018                    int64
# sat_total_2018                   int64
# dtype: object

# %%
numeric_cols = final.select_dtypes(exclude = object)

# %%
#Code:
sd = {key:man_std(key) for key in numeric_cols.columns}

# %%
sd
# Out:
# {'act_participation_rate_2017': 31.824175751231806,
#  'act_english_2017': 2.3304876369363368,
#  'act_math_2017': 1.9624620273436781,
#  'act_reading_2017': 2.046902931484265,
#  'act_science_2017': 1.7361170088327353,
#  'act_composite_2017': 2.0007860815819893,
#  'sat_participation_rate_2017': 34.929070766645076,
#  'sat_reading_writing_2017': 45.21697020437866,
#  'sat_math_2017': 46.65713364485504,
#  'sat_total_2017': 91.58351056778743,
#  'act_participation_rate_2018': 33.70173582041031,
#  'act_composite_2018': 2.0907790821411782,
#  'sat_participation_rate_2018': 36.946619223539415,
#  'sat_reading_writing_2018': 47.03460978357609,
#  'sat_math_2018': 47.301945503783536,
#  'sat_total_2018': 93.22742384464432}

# %%
np.std(final)
# Out:
# act_participation_rate_2017    31.824176
# act_english_2017                2.330488
# act_math_2017                   1.962462
# act_reading_2017                2.046903
# act_science_2017                1.736117
# act_composite_2017              2.000786
# sat_participation_rate_2017    34.929071
# sat_reading_writing_2017       45.216970
# sat_math_2017                  46.657134
# sat_total_2017                 91.583511
# act_participation_rate_2018    33.701736
# act_composite_2018              2.090779
# sat_participation_rate_2018    36.946619
# sat_reading_writing_2018       47.034610
# sat_math_2018                  47.301946
# sat_total_2018                 93.227424
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer:
# <br>
# <br>
# _The manually calculated standard deviation does not match the output we get by using the describe method._
# <br>
# _This is because pandas divides by (n-1); whereas the manual calculation only divides by n._
# <br>
# _The standard deviation using numpy.std is the same as manually calculated one because the same formula is used._

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# #### _Highest ACT Participation rate for 2017_

# %%
#code
#using filtering
final.sort_values('act_participation_rate_2017',ascending=False).loc[:, ['state','act_participation_rate_2017','act_participation_rate_2018','sat_participation_rate_2017','sat_participation_rate_2018']].head(20)
# Out:
#              state  act_participation_rate_2017  act_participation_rate_2018  \
# 0          Alabama                        100.0                        100.0
# 17        Kentucky                        100.0                        100.0
# 49       Wisconsin                        100.0                        100.0
# 44            Utah                        100.0                        100.0
# 42       Tennessee                        100.0                        100.0
# 40  South Carolina                        100.0                        100.0
# 36        Oklahoma                        100.0                        100.0
# 33  North Carolina                        100.0                        100.0
# 28          Nevada                        100.0                        100.0
# 26         Montana                        100.0                        100.0
# 24     Mississippi                        100.0                        100.0
# ...

# %% [markdown]
# _There is a 100% ACT Parcipation rates in most southern states and a few other mid-western states._
# <br>
# _ACT Participation rates are 100% for the subsequent year as well for almost all states except Colorado - which saw a reversal and has 100% participation rate for SAT in 2018._

# %% [markdown]
# #### _Lowest ACT Participation rate for 2017_

# %%
#code
final.sort_values('act_participation_rate_2017',ascending=True).loc[:, ['state','act_participation_rate_2017','act_participation_rate_2018','sat_participation_rate_2017','sat_participation_rate_2018']].head(20)
# Out:
#                    state  act_participation_rate_2017  \
# 19                 Maine                          8.0
# 29         New Hampshire                         18.0
# 7               Delaware                         18.0
# 39          Rhode Island                         21.0
# 38          Pennsylvania                         23.0
# 20              Maryland                         28.0
# 45               Vermont                         29.0
# 21         Massachusetts                         29.0
# 22              Michigan                         29.0
# 46              Virginia                         29.0
# 47            Washington                         29.0
# 4             California                         31.0
# 32              New York                         31.0
# 6            Connecticut                         31.0
# 8   District of Columbia                         32.0
# 30            New Jersey                         34.0
# ...

# %% [markdown]
# _North eastern states and have the lowest ACT Participation rates._
# <br>
# _They seem to remain low in the subsequent year._
# <br>
# _Most of these states have a mix of SAT and ACT Participation_

# %% [markdown]
# #### _Highest SAT Participation rate for 2017_

# %%
#code
final.sort_values('sat_participation_rate_2017',ascending=False).loc[:, ['state','act_participation_rate_2017','act_participation_rate_2018','sat_participation_rate_2017','sat_participation_rate_2018']].head(20)
# Out:
#                    state  act_participation_rate_2017  \
# 8   District of Columbia                         32.0
# 22              Michigan                         29.0
# 6            Connecticut                         31.0
# 7               Delaware                         18.0
# 29         New Hampshire                         18.0
# 19                 Maine                          8.0
# 12                 Idaho                         38.0
# 9                Florida                         73.0
# 21         Massachusetts                         29.0
# 39          Rhode Island                         21.0
# 30            New Jersey                         34.0
# 20              Maryland                         28.0
# 32              New York                         31.0
# 46              Virginia                         29.0
# 38          Pennsylvania                         23.0
# 47            Washington                         29.0
# ...

# %% [markdown]
# _Mostly a few eastern states seem to have 100% SAT participation rates._
# <br>
# _Other eastern states have high SAT participation rates with a decent mix of ACT participation_

# %% [markdown]
# #### Lowest SAT Participation rate for 2017_

# %%
#code
final.sort_values('sat_participation_rate_2017',ascending=True).loc[:, ['state','act_participation_rate_2017','act_participation_rate_2018','sat_participation_rate_2017','sat_participation_rate_2018']].head(20)
# Out:
#            state  act_participation_rate_2017  act_participation_rate_2018  \
# 34  North Dakota                         98.0                         98.0
# 24   Mississippi                        100.0                        100.0
# 15          Iowa                         67.0                         68.0
# 25      Missouri                        100.0                        100.0
# 44          Utah                        100.0                        100.0
# 41  South Dakota                         80.0                         77.0
# 27      Nebraska                         84.0                        100.0
# 49     Wisconsin                        100.0                        100.0
# 23     Minnesota                        100.0                         99.0
# 50       Wyoming                        100.0                        100.0
# 3       Arkansas                        100.0                        100.0
# ...

# %% [markdown]
# _The southern and mid-western states with high ACT participation have the lowest SAT participation rates_

# %% [markdown]
# #### _Highest ACT Participation rate for 2018_

# %%
#code
final.sort_values('act_participation_rate_2018',ascending=False).loc[:, ['state','act_participation_rate_2017','act_participation_rate_2018','sat_participation_rate_2017','sat_participation_rate_2018']].head(20)
# Out:
#              state  act_participation_rate_2017  act_participation_rate_2018  \
# 0          Alabama                        100.0                        100.0
# 17        Kentucky                        100.0                        100.0
# 49       Wisconsin                        100.0                        100.0
# 44            Utah                        100.0                        100.0
# 42       Tennessee                        100.0                        100.0
# 40  South Carolina                        100.0                        100.0
# 36        Oklahoma                        100.0                        100.0
# 35            Ohio                         75.0                        100.0
# 33  North Carolina                        100.0                        100.0
# 28          Nevada                        100.0                        100.0
# 27        Nebraska                         84.0                        100.0
# ...

# %% [markdown]
# _Layout very similar to what we have observed before_
# <br>
# _States with high ACT participation in 2017 continue to have high participation in 2018 with a couple converting to a complete 100%_
# <br>
# <br>
# _Majority of the sates with 100% ACT participation rates seem to imply very low SAT participation rates._

# %% [markdown]
# #### _Lowest ACT Participation rate for 2018_

# %%
#code
final.sort_values('act_participation_rate_2018',ascending=True).loc[:, ['state','act_participation_rate_2017','act_participation_rate_2018','sat_participation_rate_2017','sat_participation_rate_2018']].head(20)
# Out:
#                    state  act_participation_rate_2017  \
# 19                 Maine                          8.0
# 39          Rhode Island                         21.0
# 29         New Hampshire                         18.0
# 7               Delaware                         18.0
# 38          Pennsylvania                         23.0
# 22              Michigan                         29.0
# 47            Washington                         29.0
# 45               Vermont                         29.0
# 46              Virginia                         29.0
# 21         Massachusetts                         29.0
# 6            Connecticut                         31.0
# 4             California                         31.0
# 32              New York                         31.0
# 5               Colorado                        100.0
# 20              Maryland                         28.0
# 30            New Jersey                         34.0
# ...

# %% [markdown]
# _Similar to what we have observed before._
# <br>
# _Although low ACT participation rate does not seem to imply 100% SAT participation rate, just a higher SAT participation rate_

# %% [markdown]
# #### _Highest SAT Participation rate for 2018_

# %%
#code
final.sort_values('sat_participation_rate_2018',ascending=False).loc[:, ['state','act_participation_rate_2017','act_participation_rate_2018','sat_participation_rate_2017','sat_participation_rate_2018']].head(20)
# Out:
#                    state  act_participation_rate_2017  \
# 5               Colorado                        100.0
# 6            Connecticut                         31.0
# 7               Delaware                         18.0
# 22              Michigan                         29.0
# 12                 Idaho                         38.0
# 19                 Maine                          8.0
# 13              Illinois                         93.0
# 39          Rhode Island                         21.0
# 29         New Hampshire                         18.0
# 8   District of Columbia                         32.0
# 30            New Jersey                         34.0
# 21         Massachusetts                         29.0
# 32              New York                         31.0
# 20              Maryland                         28.0
# 38          Pennsylvania                         23.0
# 10               Georgia                         55.0
# ...

# %% [markdown]
# _Colorado and Illinois seem to have had the largest swing in SAT participation rates_

# %% [markdown]
# #### Lowest SAT Participation rate for 2018_

# %%
#using the Mask method
#The sorting method seems preferrable since you can see them in ascending/descending order
final[final['sat_participation_rate_2018']<30].loc[:,['state','act_participation_rate_2017','act_participation_rate_2018','sat_participation_rate_2017','sat_participation_rate_2018']]
# Out:
#             state  act_participation_rate_2017  act_participation_rate_2018  \
# 0         Alabama                        100.0                        100.0
# 2         Arizona                         62.0                         66.0
# 3        Arkansas                        100.0                        100.0
# 15           Iowa                         67.0                         68.0
# 16         Kansas                         73.0                         71.0
# 17       Kentucky                        100.0                        100.0
# 18      Louisiana                        100.0                        100.0
# 23      Minnesota                        100.0                         99.0
# 24    Mississippi                        100.0                        100.0
# 25       Missouri                        100.0                        100.0
# 26        Montana                        100.0                        100.0
# ...

# %% [markdown]
# _As observed before, the lowest SAT participation is in states with 100% ACT participation_

# %% [markdown]
# #### Highest Total/Composite for SAT 2017

# %%
final.sort_values('sat_total_2017',ascending=False).loc[:, ['state','sat_total_2017','sat_total_2018','act_composite_2017', 'act_composite_2018']].head(10)
# Out:
#            state  sat_total_2017  sat_total_2018  act_composite_2017  \
# 23     Minnesota            1295            1298                21.5
# 49     Wisconsin            1291            1294                20.5
# 15          Iowa            1275            1265                21.9
# 25      Missouri            1271            1262                20.4
# 16        Kansas            1260            1265                21.7
# 34  North Dakota            1256            1283                20.3
# 27      Nebraska            1253            1252                21.4
# 17      Kentucky            1247            1248                20.0
# 24   Mississippi            1242            1236                18.6
# 44          Utah            1238            1010                20.3
#
#     act_composite_2018
# 23                21.3
# 49                20.5
# 15                21.8
# 25                20.0
# 16                21.6
# 34                20.3
# 27                20.1
# ...

# %% [markdown]
# _The midwestern states seem to have the highest SAT 2017 scores_

# %% [markdown]
# #### Lowest Total/Composite for SAT 2017

# %%
final.sort_values('sat_total_2018',ascending=True).loc[:, ['state','sat_total_2017','sat_total_2018','act_composite_2017', 'act_composite_2018']].head(10)
# Out:
#                    state  sat_total_2017  sat_total_2018  act_composite_2017  \
# 8   District of Columbia             950             977                24.2
# 7               Delaware             996             998                24.1
# 48         West Virginia            1086             999                20.4
# 12                 Idaho            1005            1001                22.3
# 44                  Utah            1238            1010                20.3
# 11                Hawaii            1085            1010                19.0
# 22              Michigan            1005            1011                24.1
# 19                 Maine            1012            1013                24.3
# 39          Rhode Island            1062            1018                24.0
# 13              Illinois            1115            1019                21.4
#
#     act_composite_2018
# 8                 23.6
# 7                 23.8
# 48                20.3
# 12                22.3
# ...

# %% [markdown]
# #### Highest Total/Composite for ACT 2017

# %%
final.sort_values('act_composite_2017',ascending=False).loc[:, ['state','sat_total_2017','sat_total_2018','act_composite_2017', 'act_composite_2018']].head(10)
# Out:
#                    state  sat_total_2017  sat_total_2018  act_composite_2017  \
# 29         New Hampshire            1052            1063                25.5
# 21         Massachusetts            1107            1125                25.4
# 6            Connecticut            1041            1053                25.2
# 19                 Maine            1012            1013                24.3
# 8   District of Columbia             950             977                24.2
# 32              New York            1052            1068                24.2
# 22              Michigan            1005            1011                24.1
# 7               Delaware             996             998                24.1
# 39          Rhode Island            1062            1018                24.0
# 30            New Jersey            1056            1094                23.9
#
#     act_composite_2018
# 29                25.1
# 21                25.5
# 6                 25.6
# 19                24.0
# ...

# %% [markdown]
# #### Lowest Total/Composite for ACT 2017

# %%
final.sort_values('act_composite_2017',ascending=True).loc[:, ['state','sat_total_2017','sat_total_2018','act_composite_2017', 'act_composite_2018']].head(10)
# Out:
#              state  sat_total_2017  sat_total_2018  act_composite_2017  \
# 28          Nevada            1116            1140                17.8
# 24     Mississippi            1242            1236                18.6
# 40  South Carolina            1064            1070                18.7
# 11          Hawaii            1085            1010                19.0
# 33  North Carolina            1081            1098                19.1
# 0          Alabama            1165            1166                19.2
# 3         Arkansas            1208            1169                19.4
# 36        Oklahoma            1047            1062                19.4
# 18       Louisiana            1198            1210                19.5
# 2          Arizona            1116            1149                19.7
#
#     act_composite_2018
# 28                17.7
# 24                18.6
# 40                18.3
# 11                18.9
# 33                19.1
# 0                 19.1
# ...

# %% [markdown]
# #### Highest Total/Composite for ACT 2018

# %%
final.sort_values('act_composite_2018',ascending=False).loc[:, ['state','sat_total_2017','sat_total_2018','act_composite_2017', 'act_composite_2018']].head(10)
# Out:
#             state  sat_total_2017  sat_total_2018  act_composite_2017  \
# 6     Connecticut            1041            1053                25.2
# 21  Massachusetts            1107            1125                25.4
# 29  New Hampshire            1052            1063                25.5
# 32       New York            1052            1068                24.2
# 22       Michigan            1005            1011                24.1
# 39   Rhode Island            1062            1018                24.0
# 45        Vermont            1114            1120                23.6
# 19          Maine            1012            1013                24.3
# 13       Illinois            1115            1019                21.4
# 5        Colorado            1201            1025                20.8
#
#     act_composite_2018
# 6                 25.6
# 21                25.5
# 29                25.1
# 32                24.5
# 22                24.2
# 39                24.2
# 45                24.1
# ...

# %% [markdown]
# #### Lowest Total/Composite for ACT 2018

# %%
final.sort_values('act_composite_2018',ascending=True).loc[:, ['state','sat_total_2017','sat_total_2018','act_composite_2017', 'act_composite_2018']].head(10)
# Out:
#              state  sat_total_2017  sat_total_2018  act_composite_2017  \
# 28          Nevada            1116            1140                17.8
# 40  South Carolina            1064            1070                18.7
# 24     Mississippi            1242            1236                18.6
# 11          Hawaii            1085            1010                19.0
# 0          Alabama            1165            1166                19.2
# 33  North Carolina            1081            1098                19.1
# 2          Arizona            1116            1149                19.7
# 18       Louisiana            1198            1210                19.5
# 36        Oklahoma            1047            1062                19.4
# 3         Arkansas            1208            1169                19.4
#
#     act_composite_2018
# 28                17.7
# 40                18.3
# 24                18.6
# 11                18.9
# 0                 19.1
# 33                19.1
# ...

# %% [markdown]
# -----------------------------

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
#Heatmap
fig = plt.figure(figsize=(18,15))
mask = np.triu(np.ones_like(final.corr()))
# col_order = df.corr().sort_values('rings', ascending=False).index

ax = sns.heatmap(final.corr(), 
                 annot=True, 
                 annot_kws={'size':15}, 
                 mask=mask,
                 cmap='coolwarm')

ax.set_title('ACT and SAT Correlation', fontsize=30)
ax.tick_params(axis='x', labelsize=15, labelrotation=90)
ax.tick_params(axis='y', labelsize=15, labelrotation=0)

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(25, 10*nrows)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(list_of_titles[i], fontsize=20)
        ax[i].set_xlabel(list_of_xlabels[i], fontsize=15)
        ax[i].set_ylabel('# of States', fontsize=15)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code
columns = ['act_participation_rate_2017','act_participation_rate_2018', 'sat_participation_rate_2017', 'sat_participation_rate_2018']
titles=['ACT Participation Rate in 2017', 'ACT Participation Rate in 2018', 'SAT Participation Rate in 2017', 'SAT Participation Rate in 2018']
xlabels=['2017 ACT Participation Rate', '2018 ACT Participation Rate', '2017 SAT Participation Rate', '2018 SAT Participation Rate']

subplot_histograms(final, list_of_columns=columns,list_of_titles=titles,list_of_xlabels=xlabels)

# %% [markdown]
# _There are a lot more States with 100% participation rate for ACT as compared to SAT._
# <br>
# _There are a log more States with <10% participation rate for SAT as compared to ACT._
# <br>
# <br>
# _SAT has more states with in-between participation rates (40%-80%) as compared to the ACT. This would imply that either students prefer the test or that there is some sort of preference from states._
# <br>
# _Or since the SAT has been there for longer, this might be indicative of a slow move towards ACT._

# %% [markdown]
# #### Distribution of Math scores for SAT and ACT

# %%
subplot_histograms(final, list_of_columns=['act_math_2017', 'sat_math_2018', 'sat_math_2017'],
                   list_of_titles=['2017 ACT Math', '2018 SAT Math', '2017 SAT Math'], 
                   list_of_xlabels=['2017 ACT Math', '2018 SAT Math', '2017 SAT Math'])

# %% [markdown]
# #### Distribution of English/Reading/Writing scores for SAT and ACT

# %%
subplot_histograms(final, list_of_columns=['act_english_2017','act_reading_2017', 'sat_reading_writing_2017', 'sat_reading_writing_2018'],
                   list_of_titles=['2017 ACT English', '2017 ACT Reading', '2017 SAT Reading/Writing', '2018 SAT Reading/Writing'], 
                   list_of_xlabels=['2017 ACT English','2017 ACT Reading', '2017 SAT Reading/Writing', '2018 SAT Reading/Writing'])

# %% [markdown]
# ----------------

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Code
plt.scatter(final['sat_math_2017'], final['act_math_2017'])
plt.xlabel('sat_math_2017') 
plt.ylabel('act_math_2017')
plt.title('2017  - SAT Match scores vs ACT Math Scores', size=15)
# Out:
# Text(0.5, 1.0, '2017  - SAT Match scores vs ACT Math Scores')

# %%
plt.scatter(final['sat_reading_writing_2017'], final['act_reading_2017'])
plt.xlabel('sat_reading_writing_2017') 
plt.ylabel('act_reading_2017')
plt.title('2017 - SAT Reading/Writing vs. ACT Reading', size=16)
# Out:
# Text(0.5, 1.0, '2017 - SAT Reading/Writing vs. ACT Reading')

# %%
plt.scatter(final['sat_total_2017'], final['act_composite_2017'])
plt.xlabel('sat_total_2017') 
plt.ylabel('act_composite_2017')
plt.title('2017 - SAT Total vs. ACT Composite scores', size=16)
# Out:
# Text(0.5, 1.0, '2017 - SAT Total vs. ACT Composite scores')

# %%
plt.scatter(final['sat_total_2017'], final['sat_total_2018'])
plt.xlabel('sat_total_2017') 
plt.ylabel('sat_total_2018')
plt.title('Total SAT score 2017 vs. 2018', size=16)
# Out:
# Text(0.5, 1.0, 'Total SAT score 2017 vs. 2018')

# %%
plt.scatter(final['act_composite_2017'], final['act_composite_2018'])
plt.xlabel('act_composite_2017') 
plt.ylabel('act_composite_2018')
plt.title('Composite ACT score 2017 vs. 2018', size=16)
# Out:
# Text(0.5, 1.0, 'Composite ACT score 2017 vs. 2018')

# %% [markdown]
# ---------------

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
#Distribution of ACT Scores

plt.figure(figsize=(10,8))
sns.boxplot(data=final[['act_composite_2017', 'act_composite_2018']])
plt.ylabel('Total Score', fontsize=16)
plt.title('ACT Composite Scores', fontsize=20)
plt.xticks([0, 1], ['ACT 2017', 'ACT 2018'], fontsize=16);

# %%
#Distribution of ACT participation rates
plt.figure(figsize=(10,8))
sns.boxplot(data=final[['act_participation_rate_2017','act_participation_rate_2018']])
plt.ylabel('Rate', fontsize=16)
plt.title('ACT Participation Rates', fontsize=20)
plt.xticks([0, 1], ['ACT Participation Rate 2017', 'ACT Participation Rate 2018'], fontsize=16);

# %%
#Distribution of SAT Math Scores

plt.figure(figsize=(10,8))
sns.boxplot(data=final[['sat_math_2017','sat_math_2018']])
plt.ylabel('Total Score', fontsize=16)
plt.title('SAT Math Scores', fontsize=20)
plt.xticks([0, 1], ['SAT Math 2017', 'SAT Math 2018'], fontsize=16);

# %%
#Distribution of SAT English Scores

plt.figure(figsize=(10,8))
sns.boxplot(data=final[['sat_reading_writing_2017','sat_reading_writing_2018']])
plt.ylabel('Total Score', fontsize=16)
plt.title('SAT English Scores', fontsize=20)
plt.xticks([0, 1], ['SAT English 2017', 'SAT English 2018'], fontsize=16);

# %%
##Distribution of SAT participation rates

plt.figure(figsize=(10,8))
sns.boxplot(data=final[['sat_participation_rate_2017','sat_participation_rate_2018']])
plt.ylabel('Rate', fontsize=16)
plt.title('SAT Participation Rates', fontsize=20)
plt.xticks([0, 1], ['SAT Participation Rate 2017', 'SAT Participation Rate 2018'], fontsize=16);

# %%
##Distribution of SAT total score

plt.figure(figsize=(10,8))
sns.boxplot(data=final[['sat_total_2017','sat_total_2018']])
plt.ylabel('Total Score', fontsize=16)
plt.title('SAT Total Score', fontsize=20)
plt.xticks([0, 1], ['SAT Total 2017', 'SAT Total 2018'], fontsize=16);

# %% [markdown]
# ------

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#Participation rate and Total score seemed to have a high correlation. 
plt.figure(figsize=(10,8))
plt.scatter(final['sat_participation_rate_2017'],final['sat_total_2017'])
plt.xlabel('Participation rate', fontsize=16)
plt.ylabel('2017 SAT Total Score', fontsize=16)
plt.title('2017 - SAT Participation rate vs Total SAT Score', fontsize=20)
# Out:
# Text(0.5, 1.0, '2017 - SAT Participation rate vs Total SAT Score')

# %%
#Participation rate and Total score seemed to have a high correlation. 
plt.figure(figsize=(10,8))
plt.scatter(final['sat_participation_rate_2018'],final['sat_total_2018'])
plt.xlabel('Participation rate', fontsize=16)
plt.ylabel('2018 SAT Total Score', fontsize=16)
plt.title('2018 - SAT Participation rate vs Total SAT Score', fontsize=20)
# Out:
# Text(0.5, 1.0, '2018 - SAT Participation rate vs Total SAT Score')

# %%
#Participation rate and Total score seemed to have a high correlation. 
plt.figure(figsize=(10,8))
plt.scatter(final['act_participation_rate_2017'],final['act_composite_2017'])
plt.xlabel('Participation rate', fontsize=16)
plt.ylabel('2017 ACT Composite Score', fontsize=16)
plt.title('2017 - ACT Participation rate vs Total ACT Score', fontsize=20)
# Out:
# Text(0.5, 1.0, '2017 - ACT Participation rate vs Total ACT Score')

# %%
#Participation rate and Total score seemed to have a high correlation. 
plt.figure(figsize=(10,8))
plt.scatter(final['act_participation_rate_2018'],final['act_composite_2018'])
plt.xlabel('Participation rate', fontsize=16)
plt.ylabel('2018 ACT Composite Score', fontsize=16)
plt.title('2018 - ACT Participation rate vs Total ACT Score', fontsize=20)
# Out:
# Text(0.5, 1.0, '2018 - ACT Participation rate vs Total ACT Score')

# %% [markdown]
# _As suspected, a higher participation rate in either tests gives a lower score_
# <br>
# _This could be attributed to the fact that some students are going out of the way to give the other test (the non-prevalent test in their state). If a student goes out of their way to give a test, it would make sense that they study better for it, therefore getting a higher score_

# %%
##Comparing participation rates sides by side for 2017 and 2018

plt.figure(figsize=(10,8))
sns.boxplot(data=final[['sat_participation_rate_2017','sat_participation_rate_2018', 'act_participation_rate_2017','act_participation_rate_2018']])
plt.ylabel('Participation Rates', fontsize=16)
plt.title('Comparision of Participation Rates of SAT and ACT over 2017 and 2018', fontsize=20)
plt.xticks([0, 1,2,3], ['SAT Participation 2017', 'SAT Participation 2018', 'ACT Participation 2017', 'ACT Participation 2017'], fontsize=10)
# Out:
# ([<matplotlib.axis.XTick at 0x7fc06b6cf790>,
# ...
#  [Text(0, 0, 'SAT Participation 2017'),
#   Text(0, 0, 'SAT Participation 2018'),
#   Text(0, 0, 'ACT Participation 2017'),
#   Text(0, 0, 'ACT Participation 2017')])

# %% [markdown]
# _ACT Participation seems to have gone down slightly from 2017 to 2018._
# <br>
# _And vice-versa, SAT participation seems to have gone up.
# <br>
# <br>
# This is understandable as students only need to take either one of these for college admission. An increase in the percentage of one test can leads to a decrease in the percentage of another test._

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
plt.figure(figsize=(25,10))

sns.distplot(final['sat_math_2017'], kde = True, label='SAT Math')
sns.distplot(final['sat_reading_writing_2017'], kde = True, label='SAT Reading')

plt.legend(fontsize=20)
plt.xlabel('Score', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.title('SAT 2017 Distribution of scores', fontsize=25)
# Out:
# Text(0.5, 1.0, 'SAT 2017 Distribution of scores')

# %%
plt.figure(figsize=(25,10))

sns.distplot(final['sat_math_2018'], kde = True, label='SAT Math')
sns.distplot(final['sat_reading_writing_2018'], kde = True, label='SAT Reading')

plt.legend(fontsize=20)
plt.xlabel('Score', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.title('SAT 2018 Distribution of scores', fontsize=25)
# Out:
# Text(0.5, 1.0, 'SAT 2018 Distribution of scores')

# %%
plt.figure(figsize=(25,10))

sns.distplot(final['act_english_2017'], kde = True, label='ACT Englisg')
sns.distplot(final['act_math_2017'], kde = True, label='ACT Math')

plt.legend(fontsize=20)
plt.xlabel('Score', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.title('ACT 2017 Distribution of scores', fontsize=25)
# Out:
# Text(0.5, 1.0, 'ACT 2017 Distribution of scores')

# %%
pd.DataFrame.skew(final)
# Out:
# act_participation_rate_2017   -0.197989
# act_english_2017               0.352660
# act_math_2017                  0.332683
# act_reading_2017               0.269366
# act_science_2017               0.222050
# act_composite_2017             0.319810
# sat_participation_rate_2017    0.346450
# sat_reading_writing_2017       0.272693
# sat_math_2017                  0.365040
# sat_total_2017                 0.310903
# act_participation_rate_2018   -0.026984
# act_composite_2018             0.271560
# sat_participation_rate_2018    0.136228
# sat_reading_writing_2018       0.282300
# sat_math_2018                  0.530407
# sat_total_2018                 0.466432
# dtype: float64

# %% [markdown]
# _The individual scores are almost Normally distributed.
# <br>
# <br>
# As we have seen before in the histograms, the participation rates are skewed._
# <br>
# - _SAT participation rates are Right Skewed_
# <br>
# - _ACT participation rates are Left Skewed_

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:
# <br>
# _Since our sample size is >30, we expect the distribution to be normal, but turns out it is not so._
# <br>
# _The individual subject scores resemble a normal distribution but the participation rates are skewed_

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
# <br>
# _Most of the subject scores could be normal but they probably follow other distributions. Math is the only one that looks almost-Normal.
# The individual subject scores resemble a normal distribution but the participation rates are skewed_

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
# <br>
# _We would need more data over time to make significant inference between SAT and ACT Participation Rates_
# <br>
# _With the given data, it would not make sense to conduct a statistical inference._
# <br>
# <br>
# _Also, the participation rates do not reflect the actual number of students taking the test as populaton vary vastly state-by-state._
# <br>
# _We also have no information about the overlap between the two tests and students who might give both_

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: _No it is not appropriate. The SAT (200-800) and ACT math (1-36) scores have very large differences in terms of the scale that they use._

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:NOT COVERED

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ### Illinois:
# <br>
# Illinois has a significant change - moving from 93% ACT participation rate in 2017 to 99% SAT participation rate in 2018.
# <br>
#
# https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html

# %% [markdown]
# ### Colorado:
# <br>
# Colorado has a large swing from 2017 to 2018, most likely entirely due to a new contract acquired by the SAT in partnership with the state of Colorado. This resulted in a change of +89% for the SAT participation rates from 2017 to 2018(from 11% to 100%), and a corresponding change in ACT participation rates of -70% (from 100% to 30%).
# <br>
#
# https://www.cde.state.co.us/assessment/coloradosat

# %% [markdown]
# ### Rhode Island
# <br>
# Rhode Island had a large change as well, from 71% to 97% participation on the SAT- while ACT participation fell from 21% to 15%.
# <br>
#
#  http://www.ride.ri.gov/InstructionAssessment/Assessment/PSATandSAT.aspx

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# _The observed drastic changes in participation rates were caused due to the state department's education policies.
# <br>
# If a state were to mandate a requirement for all students to take a particular test, the participation rate for the rate would increase dramatically. From outside research, it was discovered that implementation of such policies are usually met on with high opposition from the competition._

# %% [markdown]
# _Rhode Island has made SAT testing compulsory for all students. This was implemented between 2017 and 2018 and its effects can be seen in the SAT participation, from 71% in 2017 to 97% in 2018._

# %% [markdown]
# _Illinois has also made SAT testing compulsory for all public high school students. This has caused an increase in SAT participation from 9% to 99%._

# %% [markdown]
# _Several states like decided to cover the cost of the SAT for all their public school students.
# <br>
# This contributed to the overall increase in SAT test-takers.
# <br>
# Subsidies introduced for the SAT can be seen to greatly improve SAT participation rates._

# %% [markdown]
# ### Recommendations:

# %% [markdown]
# _The most significant impact on participation rates is due to College Board's collaboration with the State Departments.
# <br>
# <br>
# Other than that, staying accessible for students and keeping them informed would be highly beneficial. This could be achieved by making the test preparation material easily accessible for students who request/need it.
# The observation that states with low participation rates have the highest scores supports this.
# <br>
# We have observed that states with low participation rates have the highest scores.
# <br>
# <br>
# The impact of subsidies is also significant. This can be supported by the observation that a lot of states with 40-80% SAT participation rates._

# %% [markdown]
# _Finally, additional research is warranted on university admissions criteria._
